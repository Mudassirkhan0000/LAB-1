# %%
#Reading Tiff Images
import rasterio
from rasterio.plot import show
from PIL import Image
img = Image.open("C:\\Users\\mk506\\Downloads\\AP_05305_FBS_F0490_RT1\\AP_05305_FBS_F0490_RT1\\AP_05305_FBS_F0490_RT1.geo.jpg")
show(img)
pixels = img.load()

# %%
pip install rasterio pillow
# Out:
# ...
#   Obtaining dependency information for rasterio from https://files.pythonhosted.org/packages/b3/0f/e7f21b87636029955ab4e0e81027dc491d99c2b6215e68c6d8f38e5291b3/rasterio-1.3.9-cp311-cp311-win_amd64.whl.metadata
# ...
#    ---------------------------------------- 0.0/23.4 MB ? eta -:--:--
#    ---------------------------------------- 0.1/23.4 MB 2.4 MB/s eta 0:00:10
#     --------------------------------------- 0.3/23.4 MB 3.0 MB/s eta 0:00:08
#     --------------------------------------- 0.6/23.4 MB 3.7 MB/s eta 0:00:07
#    - -------------------------------------- 0.7/23.4 MB 3.5 MB/s eta 0:00:07
#    - -------------------------------------- 0.7/23.4 MB 3.5 MB/s eta 0:00:07
#    - -------------------------------------- 0.7/23.4 MB 3.5 MB/s eta 0:00:07
#    - -------------------------------------- 0.8/23.4 MB 2.2 MB/s eta 0:00:11
#    - -------------------------------------- 1.1/23.4 MB 2.9 MB/s eta 0:00:08
#    -- ------------------------------------- 1.3/23.4 MB 3.0 MB/s eta 0:00:08
# ...

# %%
#Meta Data About Tiff Images
import rasterio

# Open the GeoTIFF image
with rasterio.open("C:\\Users\\mk506\\Downloads\\AP_05305_FBS_F0490_RT1\\AP_05305_FBS_F0490_RT1\\AP_05305_FBS_F0490_RT1.geo.jpg") as dataset:
    # Check the size (dimensions)
    width = dataset.width
    height = dataset.height
    print("Image Size (Width x Height):", width, "x", height)

    # Check the number of bands
    num_bands = dataset.count
    print("Number of Bands:", num_bands)
# Out:
# Image Size (Width x Height): 999 x 877
# Number of Bands: 1

# %%
dataset.count
dataset.width
dataset.height
# Out:
# 877

# %%
import matplotlib.pyplot as plt
plt.imshow(img)

# %%
import numpy as np
from PIL import Image

# Open the image
img = Image.open("C:\\Users\\mk506\\Downloads\\AP_05305_FBS_F0490_RT1\\AP_05305_FBS_F0490_RT1\\AP_05305_FBS_F0490_RT1.geo.jpg")

# Convert the image to a NumPy array
img_array = np.array(img)

# Calculate image statistics
mean = np.mean(img_array)
std_dev = np.std(img_array)
min = np.min(img_array)
max = np.max(img_array)

# Print the results
print("Mean:", mean)
print("Standard Deviation:", std_dev)
print("Min:", min)
print("Max:", max)
# Out:
# Mean: 90.74015406512557
# Standard Deviation: 70.43947119702443
# Min: 0
# Max: 255

# %%
width, height = img.size

# Print the results
print("Width:", width)
print("Height:", height)
# Out:
# Width: 999
# Height: 877

# %%
#Reducing Size of the image
import matplotlib.pyplot as plt
import cv2
import numpy as np

 
try:
    img = cv2.imread("C:\\Users\\mk506\\Downloads\\AP_05305_FBS_F0490_RT1\\AP_05305_FBS_F0490_RT1\\AP_05305_FBS_F0490_RT1.geo.jpg") 
    (height, width) = img.shape[:2]    
    res = cv2.resize(img, (int(width / 4), int(height / 4)), interpolation=cv2.INTER_CUBIC)
    cv2.imwrite('result.tiff', res)
    plt.imshow(res)
 
except IOError:
    print('Error while reading files !!!')

# %%
#Rotating Tiff Images
try:
    img = cv2.imread("C:\\Users\\mk506\\Downloads\\AP_05305_FBS_F0490_RT1\\AP_05305_FBS_F0490_RT1\\AP_05305_FBS_F0490_RT1.geo.jpg")
    (rows, cols) = img.shape[:2]
    M = cv2.getRotationMatrix2D((cols / 2, rows / 2), 180, 1)
    res1 = cv2.warpAffine(img, M, (cols, rows))
    cv2.imwrite('result.tiff', res1)
    plt.imshow(res1)
except IOError:
    print('Error while reading files !!!')

# %%
#Translating Matrix
M = np.float32([[1, 0, 100], [0, 1, 50]])
try:
    img = cv2.imread("C:\\Users\\mk506\\Downloads\\AP_05305_FBS_F0490_RT1\\AP_05305_FBS_F0490_RT1\\AP_05305_FBS_F0490_RT1.geo.jpg")
    res2 = cv2.warpAffine(img, M, (cols, rows))
    cv2.imwrite('result.tiff', res2)
    plt.imshow(res2)
 
except IOError:
    print('Error while reading files !!!')

# %%
#Canny Edge Detection
try:
    img = cv2.imread("C:\\Users\\mk506\\Downloads\\AP_05305_FBS_F0490_RT1\\AP_05305_FBS_F0490_RT1\\AP_05305_FBS_F0490_RT1.geo.jpg")
    edges = cv2.Canny(img, 15, 10)
    cv2.imwrite('result.tiff', edges)
    plt.imshow(edges)

except IOError:
    print('Error while reading files !!!')

# %%
#RGB
import cv2
import matplotlib.pyplot as plt

img2 = cv2.imread("C:\\Users\\mk506\\Downloads\\AP_05305_FBS_F0490_RT1\\AP_05305_FBS_F0490_RT1\\AP_05305_FBS_F0490_RT1.geo.jpg")
img2_rgb = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)

plt.imshow(img2_rgb)
plt.axis('off')  
plt.show()
